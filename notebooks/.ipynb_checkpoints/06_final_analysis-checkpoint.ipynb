# %%
El proyecto permitió construir un flujo de machine learning robusto y modular, incorporando técnicas supervisadas y no supervisadas.
Los hallazgos principales incluyen:

Se obtuvo un dataset limpio y consistente gracias al pipeline de procesamiento.

Los modelos supervisados lograron métricas aceptables, reflejando la capacidad predictiva del conjunto de features.

Los algoritmos no supervisados revelaron patrones claros en los datos, distinguiendo grupos según tamaño, velocidad y riesgo.

DBSCAN fue el algoritmo más adecuado para la estructura del dataset.

El uso de PCA permitió verificar visualmente la correcta separación de clusters.

La integración con Airflow y DVC asegura que el proyecto pueda escalarse, reproducirse y mantenerse a largo plazo.
